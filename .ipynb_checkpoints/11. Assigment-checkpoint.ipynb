# %% [markdown]
# In this practical assignment you will learn how to work with a package that allows you to build deep neural networks. Various neural network packages are available in Python of which Google's TensorFlow is quite famous. We will use Chainer, which is another flexible neural network package. Always show how you arrived at your answer. Hand in your assignment by adding the solutions to this notebook file.

# %% [markdown]
# ### Assignment 1 (5 points)
#
# Go to the tutorial page for Chainer:
#
# http://docs.chainer.org/en/stable/tutorial/basic.html
#
# Study <i>Example: Multi-layer Perceptron on MNIST</i>. Implement a model that learns to predict the label of a handwritten character based on the pixel input. Make sure to use a model with just *one* hidden layer consisting of *50* hidden units. Run the model for 50 epochs. Use the code below to create a figure of the training and validation loss. Make sure that you define an output directory `out_dir` for which you have write access. This should also become the value for the Trainer object's `out` argument.

# %%
import numpy as np
import chainer
from chainer import cuda, Function, gradient_check, report, training, utils, Variable
from chainer import datasets, iterators, optimizers, serializers
from chainer import Link, Chain, ChainList
import chainer.functions as F
import chainer.links as L
from chainer.training import extensions

train, test = datasets.get_mnist()
train_iter = iterators.SerialIterator(train, batch_size=100, shuffle=True)
test_iter = iterators.SerialIterator(test, batch_size=100, repeat=False, shuffle=False)

class MLP(Chain):
     def __init__(self, n_units, n_out):
         super(MLP, self).__init__(
             # the size of the inputs to each layer will be inferred
             l1=L.Linear(None, n_units),  # n_in -> n_units
             l2=L.Linear(None, n_units),  # n_units -> n_units
             l3=L.Linear(None, n_out),    # n_units -> n_out
         )

     def __call__(self, x):
         h1 = F.relu(self.l1(x))
         h2 = F.relu(self.l2(h1))
         y = self.l3(h2)
         return y
     
model = L.Classifier(MLP(50, 10))  # the input size, 784, is inferred
optimizer = optimizers.SGD()
optimizer.setup(model)

updater = training.StandardUpdater(train_iter, optimizer)
trainer = training.Trainer(updater, (20, 'epoch'), out='result')

trainer.extend(extensions.Evaluator(test_iter, model))
trainer.extend(extensions.LogReport())
trainer.extend(extensions.PrintReport(['epoch', 'main/accuracy', 'validation/main/accuracy']))
trainer.extend(extensions.ProgressBar())
trainer.run()
# Out:
# epoch       main/accuracy  validation/main/accuracy
#      total [..................................................]  0.83%
# this epoch [########..........................................] 16.67%
#        100 iter, 0 epoch / 20 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.67%
# this epoch [################..................................] 33.33%
#        200 iter, 0 epoch / 20 epochs
#     273.97 iters/sec. Estimated time to finish: 0:00:43.070001.
#      total [#.................................................]  2.50%
# this epoch [#########################.........................] 50.00%
#        300 iter, 0 epoch / 20 epochs
#     284.49 iters/sec. Estimated time to finish: 0:00:41.125504.
#      total [#.................................................]  3.33%
# this epoch [#################################.................] 66.67%
#        400 iter, 0 epoch / 20 epochs
#      252.1 iters/sec. Estimated time to finish: 0:00:46.013336.
#      total [##................................................]  4.17%
# this epoch [#########################################.........] 83.33%
#        500 iter, 0 epoch / 20 epochs
#     238.81 iters/sec. Estimated time to finish: 0:00:48.156249.
# 1           0.633133       0.8405
#      total [##................................................]  5.00%
# this epoch [..................................................]  0.00%
#        600 iter, 1 epoch / 20 epochs
#     206.78 iters/sec. Estimated time to finish: 0:00:55.130400.
#      total [##................................................]  5.83%
# this epoch [########..........................................] 16.67%
#        700 iter, 1 epoch / 20 epochs
#     206.04 iters/sec. Estimated time to finish: 0:00:54.842666.
#      total [###...............................................]  6.67%
# this epoch [################..................................] 33.33%
#        800 iter, 1 epoch / 20 epochs
#     201.67 iters/sec. Estimated time to finish: 0:00:55.535999.
#      total [###...............................................]  7.50%
# this epoch [#########################.........................] 50.00%
#        900 iter, 1 epoch / 20 epochs
#     208.44 iters/sec. Estimated time to finish: 0:00:53.252251.
#      total [####..............................................]  8.33%
# this epoch [#################################.................] 66.67%
#       1000 iter, 1 epoch / 20 epochs
#     212.06 iters/sec. Estimated time to finish: 0:00:51.871111.
#      total [####..............................................]  9.17%
# this epoch [#########################################.........] 83.33%
#       1100 iter, 1 epoch / 20 epochs
#     214.68 iters/sec. Estimated time to finish: 0:00:50.772200.
# 2           0.8639         0.8868
#      total [#####.............................................] 10.00%
# this epoch [..................................................]  0.00%
#       1200 iter, 2 epoch / 20 epochs
#     208.49 iters/sec. Estimated time to finish: 0:00:51.800727.
#      total [#####.............................................] 10.83%
# this epoch [########..........................................] 16.67%
#       1300 iter, 2 epoch / 20 epochs
#     214.13 iters/sec. Estimated time to finish: 0:00:49.969001.
#      total [#####.............................................] 11.67%
# this epoch [################..................................] 33.33%
#       1400 iter, 2 epoch / 20 epochs
#      217.5 iters/sec. Estimated time to finish: 0:00:48.735538.
#      total [######............................................] 12.50%
# this epoch [#########################.........................] 50.00%
#       1500 iter, 2 epoch / 20 epochs
#     221.34 iters/sec. Estimated time to finish: 0:00:47.437500.
#      total [######............................................] 13.33%
# this epoch [#################################.................] 66.67%
#       1600 iter, 2 epoch / 20 epochs
#     224.55 iters/sec. Estimated time to finish: 0:00:46.314667.
#      total [#######...........................................] 14.17%
# this epoch [#########################################.........] 83.33%
#       1700 iter, 2 epoch / 20 epochs
#     228.21 iters/sec. Estimated time to finish: 0:00:45.133314.
# 3           0.890533       0.9034
#      total [#######...........................................] 15.00%
# this epoch [..................................................]  0.00%
#       1800 iter, 3 epoch / 20 epochs
#     224.54 iters/sec. Estimated time to finish: 0:00:45.426001.
#      total [#######...........................................] 15.83%
# this epoch [########..........................................] 16.67%
#       1900 iter, 3 epoch / 20 epochs
#     220.67 iters/sec. Estimated time to finish: 0:00:45.769834.
#      total [########..........................................] 16.67%
# this epoch [################..................................] 33.33%
#       2000 iter, 3 epoch / 20 epochs
#     222.85 iters/sec. Estimated time to finish: 0:00:44.873684.
#      total [########..........................................] 17.50%
# this epoch [#########################.........................] 50.00%
#       2100 iter, 3 epoch / 20 epochs
#     225.35 iters/sec. Estimated time to finish: 0:00:43.931250.
#      total [#########.........................................] 18.33%
# this epoch [#################################.................] 66.67%
#       2200 iter, 3 epoch / 20 epochs
#     227.91 iters/sec. Estimated time to finish: 0:00:42.998667.
#      total [#########.........................................] 19.17%
# this epoch [#########################################.........] 83.33%
#       2300 iter, 3 epoch / 20 epochs
#     230.87 iters/sec. Estimated time to finish: 0:00:42.014227.
# 4           0.90265        0.9122
#      total [##########........................................] 20.00%
# this epoch [..................................................]  0.00%
#       2400 iter, 4 epoch / 20 epochs
#      228.2 iters/sec. Estimated time to finish: 0:00:42.068870.
#      total [##########........................................] 20.83%
# this epoch [########..........................................] 16.67%
#       2500 iter, 4 epoch / 20 epochs
#     230.77 iters/sec. Estimated time to finish: 0:00:41.166667.
#      total [##########........................................] 21.67%
# this epoch [################..................................] 33.33%
#       2600 iter, 4 epoch / 20 epochs
#     233.08 iters/sec. Estimated time to finish: 0:00:40.329760.
#      total [###########.......................................] 22.50%
# this epoch [#########################.........................] 50.00%
#       2700 iter, 4 epoch / 20 epochs
#     235.55 iters/sec. Estimated time to finish: 0:00:39.482077.
#      total [###########.......................................] 23.33%
# this epoch [#################################.................] 66.67%
#       2800 iter, 4 epoch / 20 epochs
#     237.63 iters/sec. Estimated time to finish: 0:00:38.714963.
#      total [############......................................] 24.17%
# this epoch [#########################################.........] 83.33%
#       2900 iter, 4 epoch / 20 epochs
#     239.52 iters/sec. Estimated time to finish: 0:00:37.992500.
# 5           0.910433       0.9193
#      total [############......................................] 25.00%
# this epoch [..................................................]  0.00%
#       3000 iter, 5 epoch / 20 epochs
#     237.88 iters/sec. Estimated time to finish: 0:00:37.834138.
#      total [############......................................] 25.83%
# this epoch [########..........................................] 16.67%
#       3100 iter, 5 epoch / 20 epochs
#     239.62 iters/sec. Estimated time to finish: 0:00:37.142667.
#      total [#############.....................................] 26.67%
# this epoch [################..................................] 33.33%
#       3200 iter, 5 epoch / 20 epochs
#     241.51 iters/sec. Estimated time to finish: 0:00:36.437677.
#      total [#############.....................................] 27.50%
# this epoch [#########################.........................] 50.00%
#       3300 iter, 5 epoch / 20 epochs
#     243.55 iters/sec. Estimated time to finish: 0:00:35.721656.
#      total [##############....................................] 28.33%
# this epoch [#################################.................] 66.67%
#       3400 iter, 5 epoch / 20 epochs
#      244.9 iters/sec. Estimated time to finish: 0:00:35.116667.
#      total [##############....................................] 29.17%
# this epoch [#########################################.........] 83.33%
#       3500 iter, 5 epoch / 20 epochs
#     246.61 iters/sec. Estimated time to finish: 0:00:34.467500.
# 6           0.915983       0.9223
#      total [###############...................................] 30.00%
# this epoch [..................................................]  0.00%
#       3600 iter, 6 epoch / 20 epochs
#     244.11 iters/sec. Estimated time to finish: 0:00:34.411200.
#      total [###############...................................] 30.83%
# this epoch [########..........................................] 16.67%
#       3700 iter, 6 epoch / 20 epochs
#     245.45 iters/sec. Estimated time to finish: 0:00:33.815583.
#      total [###############...................................] 31.67%
# this epoch [################..................................] 33.33%
#       3800 iter, 6 epoch / 20 epochs
#     246.83 iters/sec. Estimated time to finish: 0:00:33.221081.
#      total [################..................................] 32.50%
# this epoch [#########################.........................] 50.00%
#       3900 iter, 6 epoch / 20 epochs
#     248.03 iters/sec. Estimated time to finish: 0:00:32.657921.
#      total [################..................................] 33.33%
# this epoch [#################################.................] 66.67%
#       4000 iter, 6 epoch / 20 epochs
#     249.58 iters/sec. Estimated time to finish: 0:00:32.053333.
#      total [#################.................................] 34.17%
# this epoch [#########################################.........] 83.33%
#       4100 iter, 6 epoch / 20 epochs
#     250.78 iters/sec. Estimated time to finish: 0:00:31.501250.
# 7           0.921233       0.9263
#      total [#################.................................] 35.00%
# this epoch [..................................................]  0.00%
#       4200 iter, 7 epoch / 20 epochs
#     248.92 iters/sec. Estimated time to finish: 0:00:31.335073.
#      total [#################.................................] 35.83%
# this epoch [########..........................................] 16.67%
#       4300 iter, 7 epoch / 20 epochs
#     249.88 iters/sec. Estimated time to finish: 0:00:30.814667.
#      total [##################................................] 36.67%
# this epoch [################..................................] 33.33%
#       4400 iter, 7 epoch / 20 epochs
#     251.11 iters/sec. Estimated time to finish: 0:00:30.265675.
#      total [##################................................] 37.50%
# this epoch [#########################.........................] 50.00%
#       4500 iter, 7 epoch / 20 epochs
#     252.05 iters/sec. Estimated time to finish: 0:00:29.756250.
#      total [###################...............................] 38.33%
# this epoch [#################################.................] 66.67%
#       4600 iter, 7 epoch / 20 epochs
#     253.04 iters/sec. Estimated time to finish: 0:00:29.244800.
#      total [###################...............................] 39.17%
# this epoch [#########################################.........] 83.33%
#       4700 iter, 7 epoch / 20 epochs
#     254.23 iters/sec. Estimated time to finish: 0:00:28.714391.
# 8           0.925383       0.9305
#      total [####################..............................] 40.00%
# this epoch [..................................................]  0.00%
#       4800 iter, 8 epoch / 20 epochs
#     252.82 iters/sec. Estimated time to finish: 0:00:28.478298.
#      total [####################..............................] 40.83%
# this epoch [########..........................................] 16.67%
#       4900 iter, 8 epoch / 20 epochs
#     253.87 iters/sec. Estimated time to finish: 0:00:27.966604.
#      total [####################..............................] 41.67%
# this epoch [################..................................] 33.33%
#       5000 iter, 8 epoch / 20 epochs
#     254.89 iters/sec. Estimated time to finish: 0:00:27.462857.
#      total [#####################.............................] 42.50%
# this epoch [#########################.........................] 50.00%
#       5100 iter, 8 epoch / 20 epochs
#     255.78 iters/sec. Estimated time to finish: 0:00:26.976240.
#      total [#####################.............................] 43.33%
# this epoch [#################################.................] 66.67%
#       5200 iter, 8 epoch / 20 epochs
#        256 iters/sec. Estimated time to finish: 0:00:26.562667.
#      total [######################............................] 44.17%
# this epoch [#########################################.........] 83.33%
#       5300 iter, 8 epoch / 20 epochs
#     256.93 iters/sec. Estimated time to finish: 0:00:26.077173.
# 9           0.9288         0.9332
#      total [######################............................] 45.00%
# this epoch [..................................................]  0.00%
#       5400 iter, 9 epoch / 20 epochs
#     255.36 iters/sec. Estimated time to finish: 0:00:25.845849.
#      total [######################............................] 45.83%
# this epoch [########..........................................] 16.67%
#       5500 iter, 9 epoch / 20 epochs
#     256.29 iters/sec. Estimated time to finish: 0:00:25.362037.
#      total [#######################...........................] 46.67%
# this epoch [################..................................] 33.33%
#       5600 iter, 9 epoch / 20 epochs
#     257.08 iters/sec. Estimated time to finish: 0:00:24.894836.
#      total [#######################...........................] 47.50%
# this epoch [#########################.........................] 50.00%
#       5700 iter, 9 epoch / 20 epochs
#     257.79 iters/sec. Estimated time to finish: 0:00:24.438375.
#      total [########################..........................] 48.33%
# this epoch [#################################.................] 66.67%
#       5800 iter, 9 epoch / 20 epochs
#     258.35 iters/sec. Estimated time to finish: 0:00:23.998351.
#      total [########################..........................] 49.17%
# this epoch [#########################################.........] 83.33%
#       5900 iter, 9 epoch / 20 epochs
#     259.06 iters/sec. Estimated time to finish: 0:00:23.547052.
# 10          0.93255        0.9345
#      total [#########################.........................] 50.00%
# this epoch [..................................................]  0.00%
#       6000 iter, 10 epoch / 20 epochs
#     257.46 iters/sec. Estimated time to finish: 0:00:23.304407.
#      total [#########################.........................] 50.83%
# this epoch [########..........................................] 16.67%
#       6100 iter, 10 epoch / 20 epochs
#     258.21 iters/sec. Estimated time to finish: 0:00:22.849717.
#      total [#########################.........................] 51.67%
# this epoch [################..................................] 33.33%
#       6200 iter, 10 epoch / 20 epochs
#      258.9 iters/sec. Estimated time to finish: 0:00:22.402262.
#      total [##########################........................] 52.50%
# this epoch [#########################.........................] 50.00%
#       6300 iter, 10 epoch / 20 epochs
#     259.54 iters/sec. Estimated time to finish: 0:00:21.961548.
#      total [##########################........................] 53.33%
# this epoch [#################################.................] 66.67%
#       6400 iter, 10 epoch / 20 epochs
#     260.29 iters/sec. Estimated time to finish: 0:00:21.514667.
#      total [###########################.......................] 54.17%
# this epoch [#########################################.........] 83.33%
#       6500 iter, 10 epoch / 20 epochs
#     260.99 iters/sec. Estimated time to finish: 0:00:21.073594.
# 11          0.935417       0.9358
#      total [###########################.......................] 55.00%
# this epoch [..................................................]  0.00%
#       6600 iter, 11 epoch / 20 epochs
#     259.47 iters/sec. Estimated time to finish: 0:00:20.811600.
#      total [###########################.......................] 55.83%
# this epoch [########..........................................] 16.67%
#       6700 iter, 11 epoch / 20 epochs
#     260.13 iters/sec. Estimated time to finish: 0:00:20.374485.
#      total [############################......................] 56.67%
# this epoch [################..................................] 33.33%
#       6800 iter, 11 epoch / 20 epochs
#     260.69 iters/sec. Estimated time to finish: 0:00:19.947045.
#      total [############################......................] 57.50%
# this epoch [#########################.........................] 50.00%
#       6900 iter, 11 epoch / 20 epochs
#     261.23 iters/sec. Estimated time to finish: 0:00:19.523250.
#      total [#############################.....................] 58.33%
# this epoch [#################################.................] 66.67%
#       7000 iter, 11 epoch / 20 epochs
#     261.85 iters/sec. Estimated time to finish: 0:00:19.094928.
#      total [#############################.....................] 59.17%
# this epoch [#########################################.........] 83.33%
#       7100 iter, 11 epoch / 20 epochs
#      262.5 iters/sec. Estimated time to finish: 0:00:18.666900.
# 12          0.937667       0.9392
#      total [##############################....................] 60.00%
# this epoch [..................................................]  0.00%
#       7200 iter, 12 epoch / 20 epochs
#     260.98 iters/sec. Estimated time to finish: 0:00:18.392113.
#      total [##############################....................] 60.83%
# this epoch [########..........................................] 16.67%
#       7300 iter, 12 epoch / 20 epochs
#     261.59 iters/sec. Estimated time to finish: 0:00:17.967056.
#      total [##############################....................] 61.67%
# this epoch [################..................................] 33.33%
#       7400 iter, 12 epoch / 20 epochs
#      262.2 iters/sec. Estimated time to finish: 0:00:17.543644.
#      total [###############################...................] 62.50%
# this epoch [#########################.........................] 50.00%
#       7500 iter, 12 epoch / 20 epochs
#     262.69 iters/sec. Estimated time to finish: 0:00:17.130405.
#      total [###############################...................] 63.33%
# this epoch [#################################.................] 66.67%
#       7600 iter, 12 epoch / 20 epochs
#     263.31 iters/sec. Estimated time to finish: 0:00:16.710027.
#      total [################################..................] 64.17%
# this epoch [#########################################.........] 83.33%
#       7700 iter, 12 epoch / 20 epochs
#     263.77 iters/sec. Estimated time to finish: 0:00:16.302092.
# 13          0.940167       0.9403
#      total [################################..................] 65.00%
# this epoch [..................................................]  0.00%
#       7800 iter, 13 epoch / 20 epochs
#     262.56 iters/sec. Estimated time to finish: 0:00:15.996546.
#      total [################################..................] 65.83%
# this epoch [########..........................................] 16.67%
#       7900 iter, 13 epoch / 20 epochs
#     263.06 iters/sec. Estimated time to finish: 0:00:15.585782.
#      total [#################################.................] 66.67%
# this epoch [################..................................] 33.33%
#       8000 iter, 13 epoch / 20 epochs
#     263.65 iters/sec. Estimated time to finish: 0:00:15.171646.
#      total [#################################.................] 67.50%
# this epoch [#########################.........................] 50.00%
#       8100 iter, 13 epoch / 20 epochs
#        264 iters/sec. Estimated time to finish: 0:00:14.772712.
#      total [##################################................] 68.33%
# this epoch [#################################.................] 66.67%
#       8200 iter, 13 epoch / 20 epochs
#     264.43 iters/sec. Estimated time to finish: 0:00:14.370568.
#      total [##################################................] 69.17%
# this epoch [#########################################.........] 83.33%
#       8300 iter, 13 epoch / 20 epochs
#     264.92 iters/sec. Estimated time to finish: 0:00:13.966598.
# 14          0.94145        0.9429
#      total [###################################...............] 70.00%
# this epoch [..................................................]  0.00%
#       8400 iter, 14 epoch / 20 epochs
#     263.56 iters/sec. Estimated time to finish: 0:00:13.659181.
#      total [###################################...............] 70.83%
# this epoch [########..........................................] 16.67%
#       8500 iter, 14 epoch / 20 epochs
#     263.94 iters/sec. Estimated time to finish: 0:00:13.260833.
#      total [###################################...............] 71.67%
# this epoch [################..................................] 33.33%
#       8600 iter, 14 epoch / 20 epochs
#     264.18 iters/sec. Estimated time to finish: 0:00:12.870000.
#      total [####################################..............] 72.50%
# this epoch [#########################.........................] 50.00%
#       8700 iter, 14 epoch / 20 epochs
#     264.48 iters/sec. Estimated time to finish: 0:00:12.477453.
#      total [####################################..............] 73.33%
# this epoch [#################################.................] 66.67%
#       8800 iter, 14 epoch / 20 epochs
#     264.99 iters/sec. Estimated time to finish: 0:00:12.075770.
#      total [#####################################.............] 74.17%
# this epoch [#########################################.........] 83.33%
#       8900 iter, 14 epoch / 20 epochs
#     265.44 iters/sec. Estimated time to finish: 0:00:11.678898.
# 15          0.94455        0.9439
#      total [#####################################.............] 75.00%
# this epoch [..................................................]  0.00%
#       9000 iter, 15 epoch / 20 epochs
#     264.08 iters/sec. Estimated time to finish: 0:00:11.360225.
#      total [#####################################.............] 75.83%
# this epoch [########..........................................] 16.67%
#       9100 iter, 15 epoch / 20 epochs
#     264.56 iters/sec. Estimated time to finish: 0:00:10.961678.
#      total [######################################............] 76.67%
# this epoch [################..................................] 33.33%
#       9200 iter, 15 epoch / 20 epochs
#     265.08 iters/sec. Estimated time to finish: 0:00:10.562769.
#      total [######################################............] 77.50%
# this epoch [#########################.........................] 50.00%
#       9300 iter, 15 epoch / 20 epochs
#     265.35 iters/sec. Estimated time to finish: 0:00:10.175185.
#      total [#######################################...........] 78.33%
# this epoch [#################################.................] 66.67%
#       9400 iter, 15 epoch / 20 epochs
#     265.66 iters/sec. Estimated time to finish: 0:00:09.786903.
#      total [#######################################...........] 79.17%
# this epoch [#########################################.........] 83.33%
#       9500 iter, 15 epoch / 20 epochs
#        266 iters/sec. Estimated time to finish: 0:00:09.398670.
# 16          0.945867       0.9468
#      total [########################################..........] 80.00%
# this epoch [..................................................]  0.00%
#       9600 iter, 16 epoch / 20 epochs
#     264.84 iters/sec. Estimated time to finish: 0:00:09.062147.
#      total [########################################..........] 80.83%
# this epoch [########..........................................] 16.67%
#       9700 iter, 16 epoch / 20 epochs
#     265.11 iters/sec. Estimated time to finish: 0:00:08.675792.
#      total [########################################..........] 81.67%
# this epoch [################..................................] 33.33%
#       9800 iter, 16 epoch / 20 epochs
#     265.48 iters/sec. Estimated time to finish: 0:00:08.286969.
#      total [#########################################.........] 82.50%
# this epoch [#########################.........................] 50.00%
#       9900 iter, 16 epoch / 20 epochs
#     265.76 iters/sec. Estimated time to finish: 0:00:07.902000.
#      total [#########################################.........] 83.33%
# this epoch [#################################.................] 66.67%
#      10000 iter, 16 epoch / 20 epochs
#     266.11 iters/sec. Estimated time to finish: 0:00:07.515556.
#      total [##########################################........] 84.17%
# this epoch [#########################################.........] 83.33%
#      10100 iter, 16 epoch / 20 epochs
#     266.38 iters/sec. Estimated time to finish: 0:00:07.132790.
# 17          0.94715        0.9486
#      total [##########################################........] 85.00%
# this epoch [..................................................]  0.00%
#      10200 iter, 17 epoch / 20 epochs
#      265.3 iters/sec. Estimated time to finish: 0:00:06.784740.
#      total [##########################################........] 85.83%
# this epoch [########..........................................] 16.67%
#      10300 iter, 17 epoch / 20 epochs
#     265.38 iters/sec. Estimated time to finish: 0:00:06.405940.
#      total [###########################################.......] 86.67%
# this epoch [################..................................] 33.33%
#      10400 iter, 17 epoch / 20 epochs
#     266.55 iters/sec. Estimated time to finish: 0:00:06.002560.
#      total [###########################################.......] 87.50%
# this epoch [#########################.........................] 50.00%
#      10500 iter, 17 epoch / 20 epochs
#     267.62 iters/sec. Estimated time to finish: 0:00:05.604900.
#      total [############################################......] 88.33%
# this epoch [#################################.................] 66.67%
#      10600 iter, 17 epoch / 20 epochs
#     270.67 iters/sec. Estimated time to finish: 0:00:05.172300.
#      total [############################################......] 89.17%
# this epoch [#########################################.........] 83.33%
#      10700 iter, 17 epoch / 20 epochs
#      271.8 iters/sec. Estimated time to finish: 0:00:04.782960.
# 18          0.949167       0.9492
#      total [#############################################.....] 90.00%
# this epoch [..................................................]  0.00%
#      10800 iter, 18 epoch / 20 epochs
#     271.89 iters/sec. Estimated time to finish: 0:00:04.413480.
#      total [#############################################.....] 90.83%
# this epoch [########..........................................] 16.67%
#      10900 iter, 18 epoch / 20 epochs
#     272.17 iters/sec. Estimated time to finish: 0:00:04.041620.
#      total [#############################################.....] 91.67%
# this epoch [################..................................] 33.33%
#      11000 iter, 18 epoch / 20 epochs
#     272.72 iters/sec. Estimated time to finish: 0:00:03.666800.
#      total [##############################################....] 92.50%
# this epoch [#########################.........................] 50.00%
#      11100 iter, 18 epoch / 20 epochs
#     273.35 iters/sec. Estimated time to finish: 0:00:03.292470.
#      total [##############################################....] 93.33%
# this epoch [#################################.................] 66.67%
#      11200 iter, 18 epoch / 20 epochs
#     275.52 iters/sec. Estimated time to finish: 0:00:02.903600.
#      total [###############################################...] 94.17%
# this epoch [#########################################.........] 83.33%
#      11300 iter, 18 epoch / 20 epochs
#     275.41 iters/sec. Estimated time to finish: 0:00:02.541630.
# 19          0.950317       0.951
#      total [###############################################...] 95.00%
# this epoch [..................................................]  0.00%
#      11400 iter, 19 epoch / 20 epochs
#     274.21 iters/sec. Estimated time to finish: 0:00:02.188140.
#      total [###############################################...] 95.83%
# this epoch [########..........................................] 16.67%
#      11500 iter, 19 epoch / 20 epochs
#     274.41 iters/sec. Estimated time to finish: 0:00:01.822100.
#      total [################################################..] 96.67%
# this epoch [################..................................] 33.33%
#      11600 iter, 19 epoch / 20 epochs
#      274.1 iters/sec. Estimated time to finish: 0:00:01.459320.
#      total [################################################..] 97.50%
# this epoch [#########################.........................] 50.00%
#      11700 iter, 19 epoch / 20 epochs
#     273.82 iters/sec. Estimated time to finish: 0:00:01.095600.
#      total [#################################################.] 98.33%
# this epoch [#################################.................] 66.67%
#      11800 iter, 19 epoch / 20 epochs
#     275.63 iters/sec. Estimated time to finish: 0:00:00.725600.
#      total [#################################################.] 99.17%
# this epoch [#########################################.........] 83.33%
#      11900 iter, 19 epoch / 20 epochs
#     277.48 iters/sec. Estimated time to finish: 0:00:00.360390.
# 20          0.951883       0.9502
#      total [##################################################] 100.00%
# this epoch [..................................................]  0.00%
#      12000 iter, 20 epoch / 20 epochs
#     276.17 iters/sec. Estimated time to finish: 0:00:00.

# %%
import json
import matplotlib.pyplot as plt
# %matplotlib inline

out_dir = '/Users/Lima/Desktop/NN-17/result'

with open(out_dir + '/log') as data_file:
    data = json.load(data_file)

# extract training and testing validation loss
train_loss = map(lambda x: x['main/loss'], data)
validation_loss = map(lambda x: x['validation/main/loss'], data)

# plot training and validation error
plt.figure()
plt.plot(np.arange(len(train_loss)),np.transpose(np.vstack([train_loss,validation_loss])))
plt.legend(['training', 'validation'])
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.title('Model 1 with linear input layer')
plt.show()

# %% [markdown]
# ### Assignment 2 (5 points)
#
# In this assignment your task is to repeat the above but now using a convolutional layer as the first layer. Study chainer's `convolution2D` link function, use this to replace the first layer of the previous network, and repeat the analysis. Use 5 output channels, a stride of 3 and a padding of 0 for the convolutional layer. For convenience, we change the representation of the input data to 2D such that convolution can operate on the input image.

# %%
import numpy as np
import chainer
from chainer import cuda, Function, gradient_check, report, training, utils, Variable
from chainer import datasets, iterators, optimizers, serializers
from chainer import Link, Chain, ChainList
import chainer.functions as F
import chainer.links as L
from chainer.training import extensions

train, test = datasets.get_mnist()

Xtrain = train._datasets[0].reshape([train._datasets[0].shape[0],1,28,28])
ytrain = train._datasets[1]
Xtest = test._datasets[0].reshape([test._datasets[0].shape[0],1,28,28])
ytest = test._datasets[1]

train = datasets.TupleDataset(Xtrain,ytrain)
test = datasets.TupleDataset(Xtest,ytest)

train_iter = iterators.SerialIterator(train, batch_size=100, shuffle=True)
test_iter = iterators.SerialIterator(test, batch_size=100, repeat=False, shuffle=False)

class MLP(Chain):
     def __init__(self, n_units, n_out):
         super(MLP, self).__init__(
             # the size of the inputs to each layer will be inferred
             l1=L.Convolution2D(None, n_units, ksize=8, stride=3, pad=0),  # n_in -> n_units
             l2=L.Linear(None, n_units),  # n_units -> n_units
             l3=L.Linear(None, n_out),    # n_units -> n_out
         )

     def __call__(self, x):
         h1 = F.relu(self.l1(x))
         h2 = F.relu(self.l2(h1))
         y = self.l3(h2)
         return y
model = L.Classifier(MLP(50,10))  # the input size, 784, is inferred
optimizer = optimizers.SGD()
optimizer.setup(model)

updater = training.StandardUpdater(train_iter, optimizer)
trainer = training.Trainer(updater, (20, 'epoch'), out='result')

trainer.extend(extensions.Evaluator(test_iter, model))
trainer.extend(extensions.LogReport())
trainer.extend(extensions.PrintReport(['epoch', 'main/accuracy', 'validation/main/accuracy']))
trainer.extend(extensions.ProgressBar())
print('Training')
trainer.run()
# Out:
# Training
# epoch       main/accuracy  validation/main/accuracy
#      total [..................................................]  0.83%
# this epoch [########..........................................] 16.67%
#        100 iter, 0 epoch / 20 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.67%
# this epoch [################..................................] 33.33%
#        200 iter, 0 epoch / 20 epochs
#     58.514 iters/sec. Estimated time to finish: 0:03:21.661985.
#      total [#.................................................]  2.50%
# this epoch [#########################.........................] 50.00%
#        300 iter, 0 epoch / 20 epochs
#     58.207 iters/sec. Estimated time to finish: 0:03:21.005992.
#      total [#.................................................]  3.33%
# this epoch [#################################.................] 66.67%
#        400 iter, 0 epoch / 20 epochs
#     58.605 iters/sec. Estimated time to finish: 0:03:17.934665.
#      total [##................................................]  4.17%
# this epoch [#########################################.........] 83.33%
#        500 iter, 0 epoch / 20 epochs
#      58.78 iters/sec. Estimated time to finish: 0:03:15.643745.
# 1           0.80575        0.8997
#      total [##................................................]  5.00%
# this epoch [..................................................]  0.00%
#        600 iter, 1 epoch / 20 epochs
#     54.124 iters/sec. Estimated time to finish: 0:03:30.626398.
#      total [##................................................]  5.83%
# this epoch [########..........................................] 16.67%
#        700 iter, 1 epoch / 20 epochs
#     54.865 iters/sec. Estimated time to finish: 0:03:25.961331.
#      total [###...............................................]  6.67%
# this epoch [################..................................] 33.33%
#        800 iter, 1 epoch / 20 epochs
#     55.406 iters/sec. Estimated time to finish: 0:03:22.143997.
#      total [###...............................................]  7.50%
# this epoch [#########################.........................] 50.00%
#        900 iter, 1 epoch / 20 epochs
#     55.831 iters/sec. Estimated time to finish: 0:03:18.814875.
#      total [####..............................................]  8.33%
# this epoch [#################################.................] 66.67%
#       1000 iter, 1 epoch / 20 epochs
#     56.131 iters/sec. Estimated time to finish: 0:03:15.971110.
#      total [####..............................................]  9.17%
# this epoch [#########################################.........] 83.33%
#       1100 iter, 1 epoch / 20 epochs
#     56.392 iters/sec. Estimated time to finish: 0:03:13.289698.
# 2           0.90435        0.9162
#      total [#####.............................................] 10.00%
# this epoch [..................................................]  0.00%
#       1200 iter, 2 epoch / 20 epochs
#     54.631 iters/sec. Estimated time to finish: 0:03:17.689091.
#      total [#####.............................................] 10.83%
# this epoch [########..........................................] 16.67%
#       1300 iter, 2 epoch / 20 epochs
#     54.662 iters/sec. Estimated time to finish: 0:03:15.747582.
#      total [#####.............................................] 11.67%
# this epoch [################..................................] 33.33%
#       1400 iter, 2 epoch / 20 epochs
#     54.869 iters/sec. Estimated time to finish: 0:03:13.189076.
#      total [######............................................] 12.50%
# this epoch [#########################.........................] 50.00%
#       1500 iter, 2 epoch / 20 epochs
#     55.105 iters/sec. Estimated time to finish: 0:03:10.544999.
#      total [######............................................] 13.33%
# this epoch [#################################.................] 66.67%
#       1600 iter, 2 epoch / 20 epochs
#     55.259 iters/sec. Estimated time to finish: 0:03:08.205333.
#      total [#######...........................................] 14.17%
# this epoch [#########################################.........] 83.33%
#       1700 iter, 2 epoch / 20 epochs
#     55.479 iters/sec. Estimated time to finish: 0:03:05.657499.
# 3           0.918417       0.9264
#      total [#######...........................................] 15.00%
# this epoch [..................................................]  0.00%
#       1800 iter, 3 epoch / 20 epochs
#     54.258 iters/sec. Estimated time to finish: 0:03:07.992000.
#      total [#######...........................................] 15.83%
# this epoch [########..........................................] 16.67%
#       1900 iter, 3 epoch / 20 epochs
#     54.484 iters/sec. Estimated time to finish: 0:03:05.374277.
#      total [########..........................................] 16.67%
# this epoch [################..................................] 33.33%
#       2000 iter, 3 epoch / 20 epochs
#     54.717 iters/sec. Estimated time to finish: 0:03:02.757895.
#      total [########..........................................] 17.50%
# this epoch [#########################.........................] 50.00%
#       2100 iter, 3 epoch / 20 epochs
#     54.894 iters/sec. Estimated time to finish: 0:03:00.348300.
#      total [#########.........................................] 18.33%
# this epoch [#################################.................] 66.67%
#       2200 iter, 3 epoch / 20 epochs
#     55.013 iters/sec. Estimated time to finish: 0:02:58.140666.
#      total [#########.........................................] 19.17%
# this epoch [#########################################.........] 83.33%
#       2300 iter, 3 epoch / 20 epochs
#     54.842 iters/sec. Estimated time to finish: 0:02:56.870682.
# 4           0.927433       0.9354
#      total [##########........................................] 20.00%
# this epoch [..................................................]  0.00%
#       2400 iter, 4 epoch / 20 epochs
#     53.963 iters/sec. Estimated time to finish: 0:02:57.900522.
#      total [##########........................................] 20.83%
# this epoch [########..........................................] 16.67%
#       2500 iter, 4 epoch / 20 epochs
#     54.157 iters/sec. Estimated time to finish: 0:02:55.417500.
#      total [##########........................................] 21.67%
# this epoch [################..................................] 33.33%
#       2600 iter, 4 epoch / 20 epochs
#     54.344 iters/sec. Estimated time to finish: 0:02:52.971280.
#      total [###########.......................................] 22.50%
# this epoch [#########################.........................] 50.00%
#       2700 iter, 4 epoch / 20 epochs
#     54.408 iters/sec. Estimated time to finish: 0:02:50.930423.
#      total [###########.......................................] 23.33%
# this epoch [#################################.................] 66.67%
#       2800 iter, 4 epoch / 20 epochs
#     54.539 iters/sec. Estimated time to finish: 0:02:48.687110.
#      total [############......................................] 24.17%
# this epoch [#########################################.........] 83.33%
#       2900 iter, 4 epoch / 20 epochs
#     54.602 iters/sec. Estimated time to finish: 0:02:46.660000.
# 5           0.935517       0.9416
#      total [############......................................] 25.00%
# this epoch [..................................................]  0.00%
#       3000 iter, 5 epoch / 20 epochs
#     53.945 iters/sec. Estimated time to finish: 0:02:46.835172.
#      total [############......................................] 25.83%
# this epoch [########..........................................] 16.67%
#       3100 iter, 5 epoch / 20 epochs
#     54.057 iters/sec. Estimated time to finish: 0:02:44.641100.
#      total [#############.....................................] 26.67%
# this epoch [################..................................] 33.33%
#       3200 iter, 5 epoch / 20 epochs
#     54.227 iters/sec. Estimated time to finish: 0:02:42.280516.
#      total [#############.....................................] 27.50%
# this epoch [#########################.........................] 50.00%
#       3300 iter, 5 epoch / 20 epochs
#     54.355 iters/sec. Estimated time to finish: 0:02:40.058250.
#      total [##############....................................] 28.33%
# this epoch [#################################.................] 66.67%
#       3400 iter, 5 epoch / 20 epochs
#     54.488 iters/sec. Estimated time to finish: 0:02:37.833454.
#      total [##############....................................] 29.17%
# this epoch [#########################################.........] 83.33%
#       3500 iter, 5 epoch / 20 epochs
#      54.61 iters/sec. Estimated time to finish: 0:02:35.650000.
# 6           0.941117       0.9451
#      total [###############...................................] 30.00%
# this epoch [..................................................]  0.00%
#       3600 iter, 6 epoch / 20 epochs
#     54.075 iters/sec. Estimated time to finish: 0:02:35.340000.
#      total [###############...................................] 30.83%
# this epoch [########..........................................] 16.67%
#       3700 iter, 6 epoch / 20 epochs
#     54.166 iters/sec. Estimated time to finish: 0:02:33.231833.
#      total [###############...................................] 31.67%
# this epoch [################..................................] 33.33%
#       3800 iter, 6 epoch / 20 epochs
#     54.258 iters/sec. Estimated time to finish: 0:02:31.130432.
#      total [################..................................] 32.50%
# this epoch [#########################.........................] 50.00%
#       3900 iter, 6 epoch / 20 epochs
#     54.345 iters/sec. Estimated time to finish: 0:02:29.046394.
#      total [################..................................] 33.33%
# this epoch [#################################.................] 66.67%
#       4000 iter, 6 epoch / 20 epochs
#     54.457 iters/sec. Estimated time to finish: 0:02:26.904615.
#      total [#################.................................] 34.17%
# this epoch [#########################################.........] 83.33%
#       4100 iter, 6 epoch / 20 epochs
#     54.561 iters/sec. Estimated time to finish: 0:02:24.791200.
# 7           0.947217       0.9507
#      total [#################.................................] 35.00%
# this epoch [..................................................]  0.00%
#       4200 iter, 7 epoch / 20 epochs
#      53.91 iters/sec. Estimated time to finish: 0:02:24.684292.
#      total [#################.................................] 35.83%
# this epoch [########..........................................] 16.67%
#       4300 iter, 7 epoch / 20 epochs
#     53.992 iters/sec. Estimated time to finish: 0:02:22.615000.
#      total [##################................................] 36.67%
# this epoch [################..................................] 33.33%
#       4400 iter, 7 epoch / 20 epochs
#     54.096 iters/sec. Estimated time to finish: 0:02:20.490418.
#      total [##################................................] 37.50%
# this epoch [#########################.........................] 50.00%
#       4500 iter, 7 epoch / 20 epochs
#     54.196 iters/sec. Estimated time to finish: 0:02:18.386931.
#      total [###################...............................] 38.33%
# this epoch [#################################.................] 66.67%
#       4600 iter, 7 epoch / 20 epochs
#     54.259 iters/sec. Estimated time to finish: 0:02:16.383644.
#      total [###################...............................] 39.17%
# this epoch [#########################################.........] 83.33%
#       4700 iter, 7 epoch / 20 epochs
#      54.32 iters/sec. Estimated time to finish: 0:02:14.388239.
# 8           0.951367       0.9543
#      total [####################..............................] 40.00%
# this epoch [..................................................]  0.00%
#       4800 iter, 8 epoch / 20 epochs
#     53.932 iters/sec. Estimated time to finish: 0:02:13.500255.
#      total [####################..............................] 40.83%
# this epoch [########..........................................] 16.67%
#       4900 iter, 8 epoch / 20 epochs
#     53.996 iters/sec. Estimated time to finish: 0:02:11.492000.
#      total [####################..............................] 41.67%
# this epoch [################..................................] 33.33%
#       5000 iter, 8 epoch / 20 epochs
#     54.031 iters/sec. Estimated time to finish: 0:02:09.555714.
#      total [#####################.............................] 42.50%
# this epoch [#########################.........................] 50.00%
#       5100 iter, 8 epoch / 20 epochs
#     53.928 iters/sec. Estimated time to finish: 0:02:07.948080.
#      total [#####################.............................] 43.33%
# this epoch [#################################.................] 66.67%
#       5200 iter, 8 epoch / 20 epochs
#      53.93 iters/sec. Estimated time to finish: 0:02:06.089333.
#      total [######################............................] 44.17%
# this epoch [#########################################.........] 83.33%
#       5300 iter, 8 epoch / 20 epochs
#      53.98 iters/sec. Estimated time to finish: 0:02:04.120077.
# 9           0.955617       0.9562
#      total [######################............................] 45.00%
# this epoch [..................................................]  0.00%
#       5400 iter, 9 epoch / 20 epochs
#     53.663 iters/sec. Estimated time to finish: 0:02:02.990377.
#      total [######################............................] 45.83%
# this epoch [########..........................................] 16.67%
#       5500 iter, 9 epoch / 20 epochs
#     53.736 iters/sec. Estimated time to finish: 0:02:00.962592.
#      total [#######################...........................] 46.67%
# this epoch [################..................................] 33.33%
#       5600 iter, 9 epoch / 20 epochs
#     53.769 iters/sec. Estimated time to finish: 0:01:59.028364.
#      total [#######################...........................] 47.50%
# this epoch [#########################.........................] 50.00%
#       5700 iter, 9 epoch / 20 epochs
#     53.421 iters/sec. Estimated time to finish: 0:01:57.931500.
#      total [########################..........................] 48.33%
# this epoch [#################################.................] 66.67%
#       5800 iter, 9 epoch / 20 epochs
#     53.028 iters/sec. Estimated time to finish: 0:01:56.918947.
#      total [########################..........................] 49.17%
# this epoch [#########################################.........] 83.33%
#       5900 iter, 9 epoch / 20 epochs
#     53.035 iters/sec. Estimated time to finish: 0:01:55.018655.
# 10          0.958867       0.9615
#      total [#########################.........................] 50.00%
# this epoch [..................................................]  0.00%
#       6000 iter, 10 epoch / 20 epochs
#     52.722 iters/sec. Estimated time to finish: 0:01:53.803729.
#      total [#########################.........................] 50.83%
# this epoch [########..........................................] 16.67%
#       6100 iter, 10 epoch / 20 epochs
#     52.799 iters/sec. Estimated time to finish: 0:01:51.744033.
#      total [#########################.........................] 51.67%
# this epoch [################..................................] 33.33%
#       6200 iter, 10 epoch / 20 epochs
#     52.863 iters/sec. Estimated time to finish: 0:01:49.717934.
#      total [##########################........................] 52.50%
# this epoch [#########################.........................] 50.00%
#       6300 iter, 10 epoch / 20 epochs
#     52.883 iters/sec. Estimated time to finish: 0:01:47.785161.
#      total [##########################........................] 53.33%
# this epoch [#################################.................] 66.67%
#       6400 iter, 10 epoch / 20 epochs
#     52.941 iters/sec. Estimated time to finish: 0:01:45.777778.
#      total [###########################.......................] 54.17%
# this epoch [#########################################.........] 83.33%
#       6500 iter, 10 epoch / 20 epochs
#     53.003 iters/sec. Estimated time to finish: 0:01:43.768672.
# 11          0.9619         0.9635
#      total [###########################.......................] 55.00%
# this epoch [..................................................]  0.00%
#       6600 iter, 11 epoch / 20 epochs
#     52.721 iters/sec. Estimated time to finish: 0:01:42.425538.
#      total [###########################.......................] 55.83%
# this epoch [########..........................................] 16.67%
#       6700 iter, 11 epoch / 20 epochs
#     52.752 iters/sec. Estimated time to finish: 0:01:40.470333.
#      total [############################......................] 56.67%
# this epoch [################..................................] 33.33%
#       6800 iter, 11 epoch / 20 epochs
#     52.808 iters/sec. Estimated time to finish: 0:01:38.470149.
#      total [############################......................] 57.50%
# this epoch [#########################.........................] 50.00%
#       6900 iter, 11 epoch / 20 epochs
#      52.88 iters/sec. Estimated time to finish: 0:01:36.444750.
#      total [#############################.....................] 58.33%
# this epoch [#################################.................] 66.67%
#       7000 iter, 11 epoch / 20 epochs
#     52.933 iters/sec. Estimated time to finish: 0:01:34.458696.
#      total [#############################.....................] 59.17%
# this epoch [#########################################.........] 83.33%
#       7100 iter, 11 epoch / 20 epochs
#     53.007 iters/sec. Estimated time to finish: 0:01:32.440600.
# 12          0.9651         0.9652
#      total [##############################....................] 60.00%
# this epoch [..................................................]  0.00%
#       7200 iter, 12 epoch / 20 epochs
#     52.763 iters/sec. Estimated time to finish: 0:01:30.972845.
#      total [##############################....................] 60.83%
# this epoch [########..........................................] 16.67%
#       7300 iter, 12 epoch / 20 epochs
#     52.737 iters/sec. Estimated time to finish: 0:01:29.121139.
#      total [##############################....................] 61.67%
# this epoch [################..................................] 33.33%
#       7400 iter, 12 epoch / 20 epochs
#     52.618 iters/sec. Estimated time to finish: 0:01:27.422685.
#      total [###############################...................] 62.50%
# this epoch [#########################.........................] 50.00%
#       7500 iter, 12 epoch / 20 epochs
#     52.429 iters/sec. Estimated time to finish: 0:01:25.830203.
#      total [###############################...................] 63.33%
# this epoch [#################################.................] 66.67%
#       7600 iter, 12 epoch / 20 epochs
#     52.337 iters/sec. Estimated time to finish: 0:01:24.071093.
#      total [################################..................] 64.17%
# this epoch [#########################################.........] 83.33%
#       7700 iter, 12 epoch / 20 epochs
#     52.148 iters/sec. Estimated time to finish: 0:01:22.457592.
# 13          0.966983       0.9681
#      total [################################..................] 65.00%
# this epoch [..................................................]  0.00%
#       7800 iter, 13 epoch / 20 epochs
#     51.888 iters/sec. Estimated time to finish: 0:01:20.943273.
#      total [################################..................] 65.83%
# this epoch [########..........................................] 16.67%
#       7900 iter, 13 epoch / 20 epochs
#     51.942 iters/sec. Estimated time to finish: 0:01:18.933936.
#      total [#################################.................] 66.67%
# this epoch [################..................................] 33.33%
#       8000 iter, 13 epoch / 20 epochs
#     51.994 iters/sec. Estimated time to finish: 0:01:16.931645.
#      total [#################################.................] 67.50%
# this epoch [#########################.........................] 50.00%
#       8100 iter, 13 epoch / 20 epochs
#     52.029 iters/sec. Estimated time to finish: 0:01:14.958000.
#      total [##################################................] 68.33%
# this epoch [#################################.................] 66.67%
#       8200 iter, 13 epoch / 20 epochs
#     52.068 iters/sec. Estimated time to finish: 0:01:12.981580.
#      total [##################################................] 69.17%
# this epoch [#########################################.........] 83.33%
#       8300 iter, 13 epoch / 20 epochs
#     52.099 iters/sec. Estimated time to finish: 0:01:11.018341.
# 14          0.968833       0.9693
#      total [###################################...............] 70.00%
# this epoch [..................................................]  0.00%
#       8400 iter, 14 epoch / 20 epochs
#     51.816 iters/sec. Estimated time to finish: 0:01:09.476530.
#      total [###################################...............] 70.83%
# this epoch [########..........................................] 16.67%
#       8500 iter, 14 epoch / 20 epochs
#     51.887 iters/sec. Estimated time to finish: 0:01:07.454167.
#      total [###################################...............] 71.67%
# this epoch [################..................................] 33.33%
#       8600 iter, 14 epoch / 20 epochs
#     51.933 iters/sec. Estimated time to finish: 0:01:05.469200.
#      total [####################################..............] 72.50%
# this epoch [#########################.........................] 50.00%
#       8700 iter, 14 epoch / 20 epochs
#     51.895 iters/sec. Estimated time to finish: 0:01:03.589849.
#      total [####################################..............] 73.33%
# this epoch [#################################.................] 66.67%
#       8800 iter, 14 epoch / 20 epochs
#     51.848 iters/sec. Estimated time to finish: 0:01:01.718437.
#      total [#####################################.............] 74.17%
# this epoch [#########################################.........] 83.33%
#       8900 iter, 14 epoch / 20 epochs
#     51.809 iters/sec. Estimated time to finish: 0:00:59.834932.
# 15          0.9712         0.9711
#      total [#####################################.............] 75.00%
# this epoch [..................................................]  0.00%
#       9000 iter, 15 epoch / 20 epochs
#     51.637 iters/sec. Estimated time to finish: 0:00:58.097528.
#      total [#####################################.............] 75.83%
# this epoch [########..........................................] 16.67%
#       9100 iter, 15 epoch / 20 epochs
#     51.702 iters/sec. Estimated time to finish: 0:00:56.090511.
#      total [######################################............] 76.67%
# this epoch [################..................................] 33.33%
#       9200 iter, 15 epoch / 20 epochs
#     51.761 iters/sec. Estimated time to finish: 0:00:54.094769.
#      total [######################################............] 77.50%
# this epoch [#########################.........................] 50.00%
#       9300 iter, 15 epoch / 20 epochs
#     51.827 iters/sec. Estimated time to finish: 0:00:52.096207.
#      total [#######################################...........] 78.33%
# this epoch [#################################.................] 66.67%
#       9400 iter, 15 epoch / 20 epochs
#     51.872 iters/sec. Estimated time to finish: 0:00:50.122968.
#      total [#######################################...........] 79.17%
# this epoch [#########################################.........] 83.33%
#       9500 iter, 15 epoch / 20 epochs
#     51.935 iters/sec. Estimated time to finish: 0:00:48.136702.
# 16          0.97275        0.9719
#      total [########################################..........] 80.00%
# this epoch [..................................................]  0.00%
#       9600 iter, 16 epoch / 20 epochs
#     51.735 iters/sec. Estimated time to finish: 0:00:46.390484.
#      total [########################################..........] 80.83%
# this epoch [########..........................................] 16.67%
#       9700 iter, 16 epoch / 20 epochs
#      51.76 iters/sec. Estimated time to finish: 0:00:44.435760.
#      total [########################################..........] 81.67%
# this epoch [################..................................] 33.33%
#       9800 iter, 16 epoch / 20 epochs
#     51.821 iters/sec. Estimated time to finish: 0:00:42.453876.
#      total [#########################################.........] 82.50%
# this epoch [#########################.........................] 50.00%
#       9900 iter, 16 epoch / 20 epochs
#     51.881 iters/sec. Estimated time to finish: 0:00:40.477286.
#      total [#########################################.........] 83.33%
# this epoch [#################################.................] 66.67%
#      10000 iter, 16 epoch / 20 epochs
#     51.939 iters/sec. Estimated time to finish: 0:00:38.506667.
#      total [##########################################........] 84.17%
# this epoch [#########################################.........] 83.33%
#      10100 iter, 16 epoch / 20 epochs
#     51.988 iters/sec. Estimated time to finish: 0:00:36.546880.
# 17          0.9743         0.973
#      total [##########################################........] 85.00%
# this epoch [..................................................]  0.00%
#      10200 iter, 17 epoch / 20 epochs
#     51.776 iters/sec. Estimated time to finish: 0:00:34.764840.
#      total [##########################################........] 85.83%
# this epoch [########..........................................] 16.67%
#      10300 iter, 17 epoch / 20 epochs
#      51.78 iters/sec. Estimated time to finish: 0:00:32.831420.
#      total [###########################################.......] 86.67%
# this epoch [################..................................] 33.33%
#      10400 iter, 17 epoch / 20 epochs
#      51.78 iters/sec. Estimated time to finish: 0:00:30.899840.
#      total [###########################################.......] 87.50%
# this epoch [#########################.........................] 50.00%
#      10500 iter, 17 epoch / 20 epochs
#     51.779 iters/sec. Estimated time to finish: 0:00:28.969200.
#      total [############################################......] 88.33%
# this epoch [#################################.................] 66.67%
#      10600 iter, 17 epoch / 20 epochs
#     51.969 iters/sec. Estimated time to finish: 0:00:26.939220.
#      total [############################################......] 89.17%
# this epoch [#########################################.........] 83.33%
#      10700 iter, 17 epoch / 20 epochs
#     51.968 iters/sec. Estimated time to finish: 0:00:25.015380.
# 18          0.974983       0.9749
#      total [#############################################.....] 90.00%
# this epoch [..................................................]  0.00%
#      10800 iter, 18 epoch / 20 epochs
#     51.723 iters/sec. Estimated time to finish: 0:00:23.200680.
#      total [#############################################.....] 90.83%
# this epoch [########..........................................] 16.67%
#      10900 iter, 18 epoch / 20 epochs
#      51.66 iters/sec. Estimated time to finish: 0:00:21.293250.
#      total [#############################################.....] 91.67%
# this epoch [################..................................] 33.33%
#      11000 iter, 18 epoch / 20 epochs
#     51.658 iters/sec. Estimated time to finish: 0:00:19.358100.
#      total [##############################################....] 92.50%
# this epoch [#########################.........................] 50.00%
#      11100 iter, 18 epoch / 20 epochs
#     51.658 iters/sec. Estimated time to finish: 0:00:17.422110.
#      total [##############################################....] 93.33%
# this epoch [#################################.................] 66.67%
#      11200 iter, 18 epoch / 20 epochs
#     51.837 iters/sec. Estimated time to finish: 0:00:15.433120.
#      total [###############################################...] 94.17%
# this epoch [#########################################.........] 83.33%
#      11300 iter, 18 epoch / 20 epochs
#     51.858 iters/sec. Estimated time to finish: 0:00:13.498450.
# 19          0.97625        0.9748
#      total [###############################################...] 95.00%
# this epoch [..................................................]  0.00%
#      11400 iter, 19 epoch / 20 epochs
#     51.671 iters/sec. Estimated time to finish: 0:00:11.611860.
#      total [###############################################...] 95.83%
# this epoch [########..........................................] 16.67%
#      11500 iter, 19 epoch / 20 epochs
#     51.676 iters/sec. Estimated time to finish: 0:00:09.675750.
#      total [################################################..] 96.67%
# this epoch [################..................................] 33.33%
#      11600 iter, 19 epoch / 20 epochs
#     51.685 iters/sec. Estimated time to finish: 0:00:07.739160.
#      total [################################################..] 97.50%
# this epoch [#########################.........................] 50.00%
#      11700 iter, 19 epoch / 20 epochs
#     51.682 iters/sec. Estimated time to finish: 0:00:05.804760.
#      total [#################################################.] 98.33%
# this epoch [#################################.................] 66.67%
#      11800 iter, 19 epoch / 20 epochs
#     51.889 iters/sec. Estimated time to finish: 0:00:03.854380.
#      total [#################################################.] 99.17%
# this epoch [#########################################.........] 83.33%
#      11900 iter, 19 epoch / 20 epochs
#     51.883 iters/sec. Estimated time to finish: 0:00:01.927420.
# 20          0.9779         0.9757
#      total [##################################################] 100.00%
# this epoch [..................................................]  0.00%
#      12000 iter, 20 epoch / 20 epochs
#     51.673 iters/sec. Estimated time to finish: 0:00:00.

# %% [markdown]
# Create a scatter plot for the validation losses of models 1 and 2. What is your conclusion about the use of a convolutional layer? Explain your findings. Study the chainer documentation to get some hints for other tricks. If you continue your studies in this area, it is recommended to use low-level chainer code, to have firm control over its behavior.

# %%
import json
import matplotlib.pyplot as plt
#%matplotlib inline

out_dir = '/Users/Lima/Desktop/NN-17/result'

with open(out_dir + '/log') as data_file:
    data = json.load(data_file)

# extract training and testing validation loss
train_loss = map(lambda x: x['main/loss'], data)
validation_loss = map(lambda x: x['validation/main/loss'], data)

# plot training and validation error
plt.figure()
plt.plot(np.arange(len(train_loss)),np.transpose(np.vstack([train_loss,validation_loss])))
plt.legend(['training', 'validation'])
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.title('Model 2 with convolutional input layer')
plt.show()
