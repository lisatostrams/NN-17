# %% [markdown]
# In this practical assignment you will learn how to work with a package that allows you to build deep neural networks. Various neural network packages are available in Python of which Google's TensorFlow is quite famous. We will use Chainer, which is another flexible neural network package. Always show how you arrived at your answer. Hand in your assignment by adding the solutions to this notebook file.

# %% [markdown]
# ### Assignment 1 (5 points)
#
# Go to the tutorial page for Chainer:
#
# http://docs.chainer.org/en/stable/tutorial/basic.html
#
# Study <i>Example: Multi-layer Perceptron on MNIST</i>. Implement a model that learns to predict the label of a handwritten character based on the pixel input. Make sure to use a model with just *one* hidden layer consisting of *50* hidden units. Run the model for 50 epochs. Use the code below to create a figure of the training and validation loss. Make sure that you define an output directory `out_dir` for which you have write access. This should also become the value for the Trainer object's `out` argument.

# %%
import numpy as np
import chainer
from chainer import cuda, Function, gradient_check, report, training, utils, Variable
from chainer import datasets, iterators, optimizers, serializers
from chainer import Link, Chain, ChainList
import chainer.functions as F
import chainer.links as L
from chainer.training import extensions

train, test = datasets.get_mnist()
train_iter = iterators.SerialIterator(train, batch_size=100, shuffle=True)
test_iter = iterators.SerialIterator(test, batch_size=100, repeat=False, shuffle=False)

class MLP(Chain):
     def __init__(self, n_units, n_out):
         super(MLP, self).__init__(
             # the size of the inputs to each layer will be inferred
             l1=L.Linear(None, n_units),  # n_in -> n_units
             l2=L.Linear(None, n_units),  # n_units -> n_units
             l3=L.Linear(None, n_out),    # n_units -> n_out
         )

     def __call__(self, x):
         h1 = F.relu(self.l1(x))
         h2 = F.relu(self.l2(h1))
         y = self.l3(h2)
         return y
     
model = L.Classifier(MLP(50, 10))  # the input size, 784, is inferred
optimizer = optimizers.SGD()
optimizer.setup(model)

updater = training.StandardUpdater(train_iter, optimizer)
trainer = training.Trainer(updater, (20, 'epoch'), out='result')

trainer.extend(extensions.Evaluator(test_iter, model))
trainer.extend(extensions.LogReport())
trainer.extend(extensions.PrintReport(['epoch', 'main/accuracy', 'validation/main/accuracy']))
trainer.extend(extensions.ProgressBar())
trainer.run()
# Out:
# epoch       main/accuracy  validation/main/accuracy
#      total [..................................................]  0.83%
# this epoch [########..........................................] 16.67%
#        100 iter, 0 epoch / 20 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.67%
# this epoch [################..................................] 33.33%
#        200 iter, 0 epoch / 20 epochs
#     273.97 iters/sec. Estimated time to finish: 0:00:43.070001.
#      total [#.................................................]  2.50%
# this epoch [#########################.........................] 50.00%
#        300 iter, 0 epoch / 20 epochs
#     271.74 iters/sec. Estimated time to finish: 0:00:43.056004.
#      total [#.................................................]  3.33%
# this epoch [#################################.................] 66.67%
#        400 iter, 0 epoch / 20 epochs
#     273.22 iters/sec. Estimated time to finish: 0:00:42.456002.
#      total [##................................................]  4.17%
# this epoch [#########################################.........] 83.33%
#        500 iter, 0 epoch / 20 epochs
#     279.72 iters/sec. Estimated time to finish: 0:00:41.112502.
# 1           0.634867       0.8179
#      total [##................................................]  5.00%
# this epoch [..................................................]  0.00%
#        600 iter, 1 epoch / 20 epochs
#     249.75 iters/sec. Estimated time to finish: 0:00:45.645602.
#      total [##................................................]  5.83%
# this epoch [########..........................................] 16.67%
#        700 iter, 1 epoch / 20 epochs
#     254.99 iters/sec. Estimated time to finish: 0:00:44.314832.
#      total [###...............................................]  6.67%
# this epoch [################..................................] 33.33%
#        800 iter, 1 epoch / 20 epochs
#      258.4 iters/sec. Estimated time to finish: 0:00:43.344002.
#      total [###...............................................]  7.50%
# this epoch [#########################.........................] 50.00%
#        900 iter, 1 epoch / 20 epochs
#     261.27 iters/sec. Estimated time to finish: 0:00:42.485251.
#      total [####..............................................]  8.33%
# this epoch [#################################.................] 66.67%
#       1000 iter, 1 epoch / 20 epochs
#     260.27 iters/sec. Estimated time to finish: 0:00:42.264444.
#      total [####..............................................]  9.17%
# this epoch [#########################################.........] 83.33%
#       1100 iter, 1 epoch / 20 epochs
#     260.42 iters/sec. Estimated time to finish: 0:00:41.855999.
# 2           0.850567       0.8779
#      total [#####.............................................] 10.00%
# this epoch [..................................................]  0.00%
#       1200 iter, 2 epoch / 20 epochs
#     249.77 iters/sec. Estimated time to finish: 0:00:43.239273.
#      total [#####.............................................] 10.83%
# this epoch [########..........................................] 16.67%
#       1300 iter, 2 epoch / 20 epochs
#     253.32 iters/sec. Estimated time to finish: 0:00:42.238250.
#      total [#####.............................................] 11.67%
# this epoch [################..................................] 33.33%
#       1400 iter, 2 epoch / 20 epochs
#     256.56 iters/sec. Estimated time to finish: 0:00:41.315538.
#      total [######............................................] 12.50%
# this epoch [#########################.........................] 50.00%
#       1500 iter, 2 epoch / 20 epochs
#     258.21 iters/sec. Estimated time to finish: 0:00:40.664999.
#      total [######............................................] 13.33%
# this epoch [#################################.................] 66.67%
#       1600 iter, 2 epoch / 20 epochs
#     259.65 iters/sec. Estimated time to finish: 0:00:40.053866.
#      total [#######...........................................] 14.17%
# this epoch [#########################################.........] 83.33%
#       1700 iter, 2 epoch / 20 epochs
#     261.35 iters/sec. Estimated time to finish: 0:00:39.410375.
# 3           0.885033       0.8979
#      total [#######...........................................] 15.00%
# this epoch [..................................................]  0.00%
#       1800 iter, 3 epoch / 20 epochs
#     244.18 iters/sec. Estimated time to finish: 0:00:41.771999.
#      total [#######...........................................] 15.83%
# this epoch [########..........................................] 16.67%
#       1900 iter, 3 epoch / 20 epochs
#     242.36 iters/sec. Estimated time to finish: 0:00:41.673722.
#      total [########..........................................] 16.67%
# this epoch [################..................................] 33.33%
#       2000 iter, 3 epoch / 20 epochs
#     243.09 iters/sec. Estimated time to finish: 0:00:41.136842.
#      total [########..........................................] 17.50%
# this epoch [#########################.........................] 50.00%
#       2100 iter, 3 epoch / 20 epochs
#     238.98 iters/sec. Estimated time to finish: 0:00:41.426550.
#      total [#########.........................................] 18.33%
# this epoch [#################################.................] 66.67%
#       2200 iter, 3 epoch / 20 epochs
#     241.05 iters/sec. Estimated time to finish: 0:00:40.656000.
#      total [#########.........................................] 19.17%
# this epoch [#########################################.........] 83.33%
#       2300 iter, 3 epoch / 20 epochs
#     242.93 iters/sec. Estimated time to finish: 0:00:39.928727.
# 4           0.899433       0.9057
#      total [##########........................................] 20.00%
# this epoch [..................................................]  0.00%
#       2400 iter, 4 epoch / 20 epochs
#     238.96 iters/sec. Estimated time to finish: 0:00:40.173913.
#      total [##########........................................] 20.83%
# this epoch [########..........................................] 16.67%
#       2500 iter, 4 epoch / 20 epochs
#     241.04 iters/sec. Estimated time to finish: 0:00:39.413125.
#      total [##########........................................] 21.67%
# this epoch [################..................................] 33.33%
#       2600 iter, 4 epoch / 20 epochs
#     242.84 iters/sec. Estimated time to finish: 0:00:38.709200.
#      total [###########.......................................] 22.50%
# this epoch [#########################.........................] 50.00%
#       2700 iter, 4 epoch / 20 epochs
#      244.8 iters/sec. Estimated time to finish: 0:00:37.990500.
#      total [###########.......................................] 23.33%
# this epoch [#################################.................] 66.67%
#       2800 iter, 4 epoch / 20 epochs
#     246.35 iters/sec. Estimated time to finish: 0:00:37.345185.
#      total [############......................................] 24.17%
# this epoch [#########################################.........] 83.33%
#       2900 iter, 4 epoch / 20 epochs
#     247.77 iters/sec. Estimated time to finish: 0:00:36.728250.
# 5           0.907617       0.915
#      total [############......................................] 25.00%
# this epoch [..................................................]  0.00%
#       3000 iter, 5 epoch / 20 epochs
#     244.66 iters/sec. Estimated time to finish: 0:00:36.785172.
#      total [############......................................] 25.83%
# this epoch [########..........................................] 16.67%
#       3100 iter, 5 epoch / 20 epochs
#     245.84 iters/sec. Estimated time to finish: 0:00:36.202234.
#      total [#############.....................................] 26.67%
# this epoch [################..................................] 33.33%
#       3200 iter, 5 epoch / 20 epochs
#     244.87 iters/sec. Estimated time to finish: 0:00:35.938065.
#      total [#############.....................................] 27.50%
# this epoch [#########################.........................] 50.00%
#       3300 iter, 5 epoch / 20 epochs
#     241.73 iters/sec. Estimated time to finish: 0:00:35.990812.
#      total [##############....................................] 28.33%
# this epoch [#################################.................] 66.67%
#       3400 iter, 5 epoch / 20 epochs
#     242.54 iters/sec. Estimated time to finish: 0:00:35.458060.
#      total [##############....................................] 29.17%
# this epoch [#########################################.........] 83.33%
#       3500 iter, 5 epoch / 20 epochs
#     239.49 iters/sec. Estimated time to finish: 0:00:35.492500.
# 6           0.912867       0.9183
#      total [###############...................................] 30.00%
# this epoch [..................................................]  0.00%
#       3600 iter, 6 epoch / 20 epochs
#     235.06 iters/sec. Estimated time to finish: 0:00:35.736000.
#      total [###############...................................] 30.83%
# this epoch [########..........................................] 16.67%
#       3700 iter, 6 epoch / 20 epochs
#      236.2 iters/sec. Estimated time to finish: 0:00:35.138972.
#      total [###############...................................] 31.67%
# this epoch [################..................................] 33.33%
#       3800 iter, 6 epoch / 20 epochs
#     237.48 iters/sec. Estimated time to finish: 0:00:34.528648.
#      total [################..................................] 32.50%
# this epoch [#########################.........................] 50.00%
#       3900 iter, 6 epoch / 20 epochs
#     235.95 iters/sec. Estimated time to finish: 0:00:34.329079.
#      total [################..................................] 33.33%
# this epoch [#################################.................] 66.67%
#       4000 iter, 6 epoch / 20 epochs
#     235.32 iters/sec. Estimated time to finish: 0:00:33.995897.
#      total [#################.................................] 34.17%
# this epoch [#########################################.........] 83.33%
#       4100 iter, 6 epoch / 20 epochs
#     235.67 iters/sec. Estimated time to finish: 0:00:33.521675.
# 7           0.917333       0.9235
#      total [#################.................................] 35.00%
# this epoch [..................................................]  0.00%
#       4200 iter, 7 epoch / 20 epochs
#     233.57 iters/sec. Estimated time to finish: 0:00:33.395414.
#      total [#################.................................] 35.83%
# this epoch [########..........................................] 16.67%
#       4300 iter, 7 epoch / 20 epochs
#     234.31 iters/sec. Estimated time to finish: 0:00:32.862500.
#      total [##################................................] 36.67%
# this epoch [################..................................] 33.33%
#       4400 iter, 7 epoch / 20 epochs
#      234.6 iters/sec. Estimated time to finish: 0:00:32.395442.
#      total [##################................................] 37.50%
# this epoch [#########################.........................] 50.00%
#       4500 iter, 7 epoch / 20 epochs
#     234.92 iters/sec. Estimated time to finish: 0:00:31.926136.
#      total [###################...............................] 38.33%
# this epoch [#################################.................] 66.67%
#       4600 iter, 7 epoch / 20 epochs
#     235.89 iters/sec. Estimated time to finish: 0:00:31.371067.
#      total [###################...............................] 39.17%
# this epoch [#########################################.........] 83.33%
#       4700 iter, 7 epoch / 20 epochs
#     236.88 iters/sec. Estimated time to finish: 0:00:30.817109.
# 8           0.9214         0.9252
#      total [####################..............................] 40.00%
# this epoch [..................................................]  0.00%
#       4800 iter, 8 epoch / 20 epochs
#     235.35 iters/sec. Estimated time to finish: 0:00:30.592340.
#      total [####################..............................] 40.83%
# this epoch [########..........................................] 16.67%
#       4900 iter, 8 epoch / 20 epochs
#      236.3 iters/sec. Estimated time to finish: 0:00:30.046312.
#      total [####################..............................] 41.67%
# this epoch [################..................................] 33.33%
#       5000 iter, 8 epoch / 20 epochs
#     237.17 iters/sec. Estimated time to finish: 0:00:29.514286.
#      total [#####################.............................] 42.50%
# this epoch [#########################.........................] 50.00%
#       5100 iter, 8 epoch / 20 epochs
#     238.33 iters/sec. Estimated time to finish: 0:00:28.951020.
#      total [#####################.............................] 43.33%
# this epoch [#################################.................] 66.67%
#       5200 iter, 8 epoch / 20 epochs
#     239.21 iters/sec. Estimated time to finish: 0:00:28.426667.
#      total [######################............................] 44.17%
# this epoch [#########################################.........] 83.33%
#       5300 iter, 8 epoch / 20 epochs
#     239.95 iters/sec. Estimated time to finish: 0:00:27.922250.
# 9           0.924933       0.9295
#      total [######################............................] 45.00%
# this epoch [..................................................]  0.00%
#       5400 iter, 9 epoch / 20 epochs
#     238.76 iters/sec. Estimated time to finish: 0:00:27.642792.
#      total [######################............................] 45.83%
# this epoch [########..........................................] 16.67%
#       5500 iter, 9 epoch / 20 epochs
#     239.73 iters/sec. Estimated time to finish: 0:00:27.113426.
#      total [#######################...........................] 46.67%
# this epoch [################..................................] 33.33%
#       5600 iter, 9 epoch / 20 epochs
#     240.58 iters/sec. Estimated time to finish: 0:00:26.601891.
#      total [#######################...........................] 47.50%
# this epoch [#########################.........................] 50.00%
#       5700 iter, 9 epoch / 20 epochs
#     241.31 iters/sec. Estimated time to finish: 0:00:26.107875.
#      total [########################..........................] 48.33%
# this epoch [#################################.................] 66.67%
#       5800 iter, 9 epoch / 20 epochs
#     242.02 iters/sec. Estimated time to finish: 0:00:25.617965.
#      total [########################..........................] 49.17%
# this epoch [#########################################.........] 83.33%
#       5900 iter, 9 epoch / 20 epochs
#      242.9 iters/sec. Estimated time to finish: 0:00:25.113069.
# 10          0.927683       0.9323
#      total [#########################.........................] 50.00%
# this epoch [..................................................]  0.00%
#       6000 iter, 10 epoch / 20 epochs
#      241.6 iters/sec. Estimated time to finish: 0:00:24.834915.
#      total [#########################.........................] 50.83%
# this epoch [########..........................................] 16.67%
#       6100 iter, 10 epoch / 20 epochs
#     242.35 iters/sec. Estimated time to finish: 0:00:24.345367.
#      total [#########################.........................] 51.67%
# this epoch [################..................................] 33.33%
#       6200 iter, 10 epoch / 20 epochs
#     243.13 iters/sec. Estimated time to finish: 0:00:23.855115.
#      total [##########################........................] 52.50%
# this epoch [#########################.........................] 50.00%
#       6300 iter, 10 epoch / 20 epochs
#     243.86 iters/sec. Estimated time to finish: 0:00:23.373677.
#      total [##########################........................] 53.33%
# this epoch [#################################.................] 66.67%
#       6400 iter, 10 epoch / 20 epochs
#     244.54 iters/sec. Estimated time to finish: 0:00:22.900444.
#      total [###########################.......................] 54.17%
# this epoch [#########################################.........] 83.33%
#       6500 iter, 10 epoch / 20 epochs
#     245.03 iters/sec. Estimated time to finish: 0:00:22.446016.
# 11          0.930417       0.9334
#      total [###########################.......................] 55.00%
# this epoch [..................................................]  0.00%
#       6600 iter, 11 epoch / 20 epochs
#      243.8 iters/sec. Estimated time to finish: 0:00:22.149138.
#      total [###########################.......................] 55.83%
# this epoch [########..........................................] 16.67%
#       6700 iter, 11 epoch / 20 epochs
#     244.49 iters/sec. Estimated time to finish: 0:00:21.677803.
#      total [############################......................] 56.67%
# this epoch [################..................................] 33.33%
#       6800 iter, 11 epoch / 20 epochs
#     245.19 iters/sec. Estimated time to finish: 0:00:21.208239.
#      total [############################......................] 57.50%
# this epoch [#########################.........................] 50.00%
#       6900 iter, 11 epoch / 20 epochs
#     245.97 iters/sec. Estimated time to finish: 0:00:20.734500.
#      total [#############################.....................] 58.33%
# this epoch [#################################.................] 66.67%
#       7000 iter, 11 epoch / 20 epochs
#     246.44 iters/sec. Estimated time to finish: 0:00:20.289130.
#      total [#############################.....................] 59.17%
# this epoch [#########################################.........] 83.33%
#       7100 iter, 11 epoch / 20 epochs
#     246.92 iters/sec. Estimated time to finish: 0:00:19.844300.
# 12          0.933883       0.9354
#      total [##############################....................] 60.00%
# this epoch [..................................................]  0.00%
#       7200 iter, 12 epoch / 20 epochs
#     245.58 iters/sec. Estimated time to finish: 0:00:19.545465.
#      total [##############################....................] 60.83%
# this epoch [########..........................................] 16.67%
#       7300 iter, 12 epoch / 20 epochs
#     246.15 iters/sec. Estimated time to finish: 0:00:19.093750.
#      total [##############################....................] 61.67%
# this epoch [################..................................] 33.33%
#       7400 iter, 12 epoch / 20 epochs
#     246.77 iters/sec. Estimated time to finish: 0:00:18.640712.
#      total [###############################...................] 62.50%
# this epoch [#########################.........................] 50.00%
#       7500 iter, 12 epoch / 20 epochs
#     246.96 iters/sec. Estimated time to finish: 0:00:18.221351.
#      total [###############################...................] 63.33%
# this epoch [#################################.................] 66.67%
#       7600 iter, 12 epoch / 20 epochs
#     247.13 iters/sec. Estimated time to finish: 0:00:17.804160.
#      total [################################..................] 64.17%
# this epoch [#########################################.........] 83.33%
#       7700 iter, 12 epoch / 20 epochs
#     247.64 iters/sec. Estimated time to finish: 0:00:17.364079.
# 13          0.93595        0.9381
#      total [################################..................] 65.00%
# this epoch [..................................................]  0.00%
#       7800 iter, 13 epoch / 20 epochs
#     246.39 iters/sec. Estimated time to finish: 0:00:17.046000.
#      total [################################..................] 65.83%
# this epoch [########..........................................] 16.67%
#       7900 iter, 13 epoch / 20 epochs
#     246.94 iters/sec. Estimated time to finish: 0:00:16.603423.
#      total [#################################.................] 66.67%
# this epoch [################..................................] 33.33%
#       8000 iter, 13 epoch / 20 epochs
#     247.53 iters/sec. Estimated time to finish: 0:00:16.159494.
#      total [#################################.................] 67.50%
# this epoch [#########################.........................] 50.00%
#       8100 iter, 13 epoch / 20 epochs
#     247.96 iters/sec. Estimated time to finish: 0:00:15.728213.
#      total [##################################................] 68.33%
# this epoch [#################################.................] 66.67%
#       8200 iter, 13 epoch / 20 epochs
#     248.43 iters/sec. Estimated time to finish: 0:00:15.296173.
#      total [##################################................] 69.17%
# this epoch [#########################################.........] 83.33%
#       8300 iter, 13 epoch / 20 epochs
#     248.92 iters/sec. Estimated time to finish: 0:00:14.864073.
# 14          0.93905        0.9395
#      total [###################################...............] 70.00%
# this epoch [..................................................]  0.00%
#       8400 iter, 14 epoch / 20 epochs
#     247.84 iters/sec. Estimated time to finish: 0:00:14.525783.
#      total [###################################...............] 70.83%
# this epoch [########..........................................] 16.67%
#       8500 iter, 14 epoch / 20 epochs
#      248.4 iters/sec. Estimated time to finish: 0:00:14.090000.
#      total [###################################...............] 71.67%
# this epoch [################..................................] 33.33%
#       8600 iter, 14 epoch / 20 epochs
#     248.92 iters/sec. Estimated time to finish: 0:00:13.659200.
#      total [####################################..............] 72.50%
# this epoch [#########################.........................] 50.00%
#       8700 iter, 14 epoch / 20 epochs
#     249.33 iters/sec. Estimated time to finish: 0:00:13.235302.
#      total [####################################..............] 73.33%
# this epoch [#################################.................] 66.67%
#       8800 iter, 14 epoch / 20 epochs
#     249.71 iters/sec. Estimated time to finish: 0:00:12.815080.
#      total [#####################################.............] 74.17%
# this epoch [#########################################.........] 83.33%
#       8900 iter, 14 epoch / 20 epochs
#     249.96 iters/sec. Estimated time to finish: 0:00:12.402114.
# 15          0.941017       0.9405
#      total [#####################################.............] 75.00%
# this epoch [..................................................]  0.00%
#       9000 iter, 15 epoch / 20 epochs
#     248.87 iters/sec. Estimated time to finish: 0:00:12.054270.
#      total [#####################################.............] 75.83%
# this epoch [########..........................................] 16.67%
#       9100 iter, 15 epoch / 20 epochs
#     249.26 iters/sec. Estimated time to finish: 0:00:11.634478.
#      total [######################################............] 76.67%
# this epoch [################..................................] 33.33%
#       9200 iter, 15 epoch / 20 epochs
#     249.67 iters/sec. Estimated time to finish: 0:00:11.214769.
#      total [######################################............] 77.50%
# this epoch [#########################.........................] 50.00%
#       9300 iter, 15 epoch / 20 epochs
#     250.02 iters/sec. Estimated time to finish: 0:00:10.799120.
#      total [#######################################...........] 78.33%
# this epoch [#################################.................] 66.67%
#       9400 iter, 15 epoch / 20 epochs
#     250.39 iters/sec. Estimated time to finish: 0:00:10.383785.
#      total [#######################################...........] 79.17%
# this epoch [#########################################.........] 83.33%
#       9500 iter, 15 epoch / 20 epochs
#     250.73 iters/sec. Estimated time to finish: 0:00:09.970745.
# 16          0.942767       0.942
#      total [########################################..........] 80.00%
# this epoch [..................................................]  0.00%
#       9600 iter, 16 epoch / 20 epochs
#     249.72 iters/sec. Estimated time to finish: 0:00:09.610611.
#      total [########################################..........] 80.83%
# this epoch [########..........................................] 16.67%
#       9700 iter, 16 epoch / 20 epochs
#      250.1 iters/sec. Estimated time to finish: 0:00:09.196167.
#      total [########################################..........] 81.67%
# this epoch [################..................................] 33.33%
#       9800 iter, 16 epoch / 20 epochs
#     250.44 iters/sec. Estimated time to finish: 0:00:08.784577.
#      total [#########################################.........] 82.50%
# this epoch [#########################.........................] 50.00%
#       9900 iter, 16 epoch / 20 epochs
#     250.65 iters/sec. Estimated time to finish: 0:00:08.378143.
#      total [#########################################.........] 83.33%
# this epoch [#################################.................] 66.67%
#      10000 iter, 16 epoch / 20 epochs
#     251.03 iters/sec. Estimated time to finish: 0:00:07.967071.
#      total [##########################################........] 84.17%
# this epoch [#########################################.........] 83.33%
#      10100 iter, 16 epoch / 20 epochs
#     251.37 iters/sec. Estimated time to finish: 0:00:07.558580.
# 17          0.944383       0.9447
#      total [##########################################........] 85.00%
# this epoch [..................................................]  0.00%
#      10200 iter, 17 epoch / 20 epochs
#     250.18 iters/sec. Estimated time to finish: 0:00:07.194780.
#      total [##########################################........] 85.83%
# this epoch [########..........................................] 16.67%
#      10300 iter, 17 epoch / 20 epochs
#     250.35 iters/sec. Estimated time to finish: 0:00:06.790480.
#      total [###########################################.......] 86.67%
# this epoch [################..................................] 33.33%
#      10400 iter, 17 epoch / 20 epochs
#     250.49 iters/sec. Estimated time to finish: 0:00:06.387360.
#      total [###########################################.......] 87.50%
# this epoch [#########################.........................] 50.00%
#      10500 iter, 17 epoch / 20 epochs
#     250.41 iters/sec. Estimated time to finish: 0:00:05.990250.
#      total [############################################......] 88.33%
# this epoch [#################################.................] 66.67%
#      10600 iter, 17 epoch / 20 epochs
#     251.95 iters/sec. Estimated time to finish: 0:00:05.556740.
#      total [############################################......] 89.17%
# this epoch [#########################################.........] 83.33%
#      10700 iter, 17 epoch / 20 epochs
#     251.93 iters/sec. Estimated time to finish: 0:00:05.160090.
# 18          0.947017       0.9463
#      total [#############################################.....] 90.00%
# this epoch [..................................................]  0.00%
#      10800 iter, 18 epoch / 20 epochs
#     250.77 iters/sec. Estimated time to finish: 0:00:04.785240.
#      total [#############################################.....] 90.83%
# this epoch [########..........................................] 16.67%
#      10900 iter, 18 epoch / 20 epochs
#     250.72 iters/sec. Estimated time to finish: 0:00:04.387350.
#      total [#############################################.....] 91.67%
# this epoch [################..................................] 33.33%
#      11000 iter, 18 epoch / 20 epochs
#     250.75 iters/sec. Estimated time to finish: 0:00:03.988100.
#      total [##############################################....] 92.50%
# this epoch [#########################.........................] 50.00%
#      11100 iter, 18 epoch / 20 epochs
#     250.88 iters/sec. Estimated time to finish: 0:00:03.587310.
#      total [##############################################....] 93.33%
# this epoch [#################################.................] 66.67%
#      11200 iter, 18 epoch / 20 epochs
#     251.49 iters/sec. Estimated time to finish: 0:00:03.181040.
#      total [###############################################...] 94.17%
# this epoch [#########################################.........] 83.33%
#      11300 iter, 18 epoch / 20 epochs
#     250.52 iters/sec. Estimated time to finish: 0:00:02.794190.
# 19          0.94825        0.9465
#      total [###############################################...] 95.00%
# this epoch [..................................................]  0.00%
#      11400 iter, 19 epoch / 20 epochs
#     247.53 iters/sec. Estimated time to finish: 0:00:02.423940.
#      total [###############################################...] 95.83%
# this epoch [########..........................................] 16.67%
#      11500 iter, 19 epoch / 20 epochs
#     246.69 iters/sec. Estimated time to finish: 0:00:02.026850.
#      total [################################################..] 96.67%
# this epoch [################..................................] 33.33%
#      11600 iter, 19 epoch / 20 epochs
#     246.79 iters/sec. Estimated time to finish: 0:00:01.620840.
#      total [################################################..] 97.50%
# this epoch [#########################.........................] 50.00%
#      11700 iter, 19 epoch / 20 epochs
#     246.87 iters/sec. Estimated time to finish: 0:00:01.215210.
#      total [#################################################.] 98.33%
# this epoch [#################################.................] 66.67%
#      11800 iter, 19 epoch / 20 epochs
#     250.04 iters/sec. Estimated time to finish: 0:00:00.799860.
#      total [#################################################.] 99.17%
# this epoch [#########################################.........] 83.33%
#      11900 iter, 19 epoch / 20 epochs
#     250.79 iters/sec. Estimated time to finish: 0:00:00.398740.
# 20          0.949367       0.9499
#      total [##################################################] 100.00%
# this epoch [..................................................]  0.00%
#      12000 iter, 20 epoch / 20 epochs
#     249.96 iters/sec. Estimated time to finish: 0:00:00.

# %%
import json
import matplotlib.pyplot as plt
# %matplotlib inline

out_dir = '/Users/Lima/Desktop/NN-17/result'

with open(out_dir + '/log') as data_file:
    data = json.load(data_file)

# extract training and testing validation loss
train_loss = map(lambda x: x['main/loss'], data)
validation_loss = map(lambda x: x['validation/main/loss'], data)

# plot training and validation error
plt.figure()
plt.plot(np.arange(len(train_loss)),np.transpose(np.vstack([train_loss,validation_loss])))
plt.legend(['training', 'validation'])
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# ### Assignment 2 (5 points)
#
# In this assignment your task is to repeat the above but now using a convolutional layer as the first layer. Study chainer's `convolution2D` link function, use this to replace the first layer of the previous network, and repeat the analysis. Use 5 output channels, a stride of 3 and a padding of 0 for the convolutional layer. For convenience, we change the representation of the input data to 2D such that convolution can operate on the input image.

# %%
import numpy as np
import chainer
from chainer import cuda, Function, gradient_check, report, training, utils, Variable
from chainer import datasets, iterators, optimizers, serializers
from chainer import Link, Chain, ChainList
import chainer.functions as F
import chainer.links as L
from chainer.training import extensions

train, test = datasets.get_mnist()
train_iter = iterators.SerialIterator(train, batch_size=100, shuffle=True)
test_iter = iterators.SerialIterator(test, batch_size=100, repeat=False, shuffle=False)
Xtrain = train._datasets[0].reshape([train._datasets[0].shape[0],1,28,28])
ytrain = train._datasets[1]
Xtest = test._datasets[0].reshape([test._datasets[0].shape[0],1,28,28])
ytest = test._datasets[1]

train = datasets.TupleDataset(Xtrain,ytrain)
test = datasets.TupleDataset(Xtest,ytest)

class MLP(Chain):
     def __init__(self, n_units, n_out):
         super(MLP, self).__init__(
             # the size of the inputs to each layer will be inferred
             l1=L.Convolution2D(None, n_units, ksize=1, stride=3, pad=0),  # n_in -> n_units
             l2=L.Linear(None, n_units),  # n_units -> n_units
             l3=L.Linear(None, n_out),    # n_units -> n_out
         )

     def __call__(self, x):
         h1 = F.relu(self.l1(x))
         h2 = F.relu(self.l2(h1))
         y = self.l3(h2)
         return y
     
model = L.Classifier(MLP(50, 5))  # the input size, 784, is inferred
optimizer = optimizers.SGD()
optimizer.setup(model)

updater = training.StandardUpdater(train_iter, optimizer)
trainer = training.Trainer(updater, (20, 'epoch'), out='result')

trainer.extend(extensions.Evaluator(test_iter, model))
trainer.extend(extensions.LogReport())
trainer.extend(extensions.PrintReport(['epoch', 'main/accuracy', 'validation/main/accuracy']))
trainer.extend(extensions.ProgressBar())
trainer.run()  


import json
import matplotlib.pyplot as plt
#%matplotlib inline

out_dir = '/Users/Lima/Desktop/NN-17/result'

with open(out_dir + '/log') as data_file:
    data = json.load(data_file)

# extract training and testing validation loss
train_loss = map(lambda x: x['main/loss'], data)
validation_loss = map(lambda x: x['validation/main/loss'], data)

# plot training and validation error
plt.figure()
plt.plot(np.arange(len(train_loss)),np.transpose(np.vstack([train_loss,validation_loss])))
plt.legend(['training', 'validation'])
plt.xlabel('epoch')
plt.ylabel('MSE')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidType                               Traceback (most recent call last)
# <ipython-input-1-270d017aeda1> in <module>()
#      46 trainer.extend(extensions.PrintReport(['epoch', 'main/accuracy', 'validation/main/accuracy']))
#      47 trainer.extend(extensions.ProgressBar())
# ---> 48 trainer.run()
#      49
#      50
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\training\trainer.pyc in run(self)
#     293                 self.observation = {}
#     294                 with reporter.scope(self.observation):
# --> 295                     update()
#     296                     for name, entry in extensions:
#     297                         if entry.trigger(self):
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\training\updater.pyc in update(self)
#     175
#     176     def update(self):
# --> 177         self.update_core()
#     178         self.iteration += 1
#     179
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\training\updater.pyc in update_core(self)
#     187         if isinstance(in_arrays, tuple):
#     188             in_vars = tuple(variable.Variable(x) for x in in_arrays)
# --> 189             optimizer.update(loss_func, *in_vars)
#     190         elif isinstance(in_arrays, dict):
#     191             in_vars = {key: variable.Variable(x)
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\optimizer.pyc in update(self, lossfun, *args, **kwds)
#     409         if lossfun is not None:
#     410             use_cleargrads = getattr(self, '_use_cleargrads', False)
# --> 411             loss = lossfun(*args, **kwds)
#     412             if use_cleargrads:
#     413                 self.target.cleargrads()
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\links\model\classifier.pyc in __call__(self, *args)
#      65         self.loss = None
#      66         self.accuracy = None
# ---> 67         self.y = self.predictor(*x)
#      68         self.loss = self.lossfun(self.y, t)
#      69         reporter.report({'loss': self.loss}, self)
#
# <ipython-input-1-270d017aeda1> in __call__(self, x)
#      30
#      31      def __call__(self, x):
# ---> 32          h1 = F.relu(self.l1(x))
#      33          h2 = F.relu(self.l2(h1))
#      34          y = self.l3(h2)
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\links\connection\convolution_2d.pyc in __call__(self, x)
#     107         return convolution_2d.convolution_2d(
#     108             x, self.W, self.b, self.stride, self.pad, self.use_cudnn,
# --> 109             deterministic=self.deterministic)
#     110
#     111
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\functions\connection\convolution_2d.pyc in convolution_2d(x, W, b, stride, pad, use_cudnn, cover_all, deterministic)
#     415         return func(x, W)
#     416     else:
# --> 417         return func(x, W, b)
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\function.pyc in __call__(self, *inputs)
#     187
#     188         if self.type_check_enable:
# --> 189             self._check_data_type_forward(in_data)
#     190
#     191         hooks = chainer.get_function_hooks()
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\function.pyc in _check_data_type_forward(self, in_data)
#     271         in_type = type_check.get_types(in_data, 'in_types', False)
#     272         with type_check.get_function_check_context(self):
# --> 273             self.check_type_forward(in_type)
#     274
#     275     def check_type_forward(self, in_types):
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\functions\connection\convolution_2d.pyc in check_type_forward(self, in_types)
#      50             x_type.ndim == 4,
#      51             w_type.ndim == 4,
# ---> 52             x_type.shape[1] == w_type.shape[1],
#      53         )
#      54
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\utils\type_check.pyc in expect(*bool_exprs)
#     485     for expr in bool_exprs:
#     486         assert isinstance(expr, Testable)
# --> 487         expr.expect()
#     488
#     489
#
# C:\Users\Lima\Anaconda2\lib\site-packages\chainer\utils\type_check.pyc in expect(self)
#     447             raise InvalidType(
#     448                 '{0} {1} {2}'.format(self.lhs, self.exp, self.rhs),
# --> 449                 '{0} {1} {2}'.format(left, self.inv, right))
#     450
#     451
#
# InvalidType:
# Invalid operation is performed in: Convolution2DFunction (Forward)
#
# Expect: in_types[0].ndim == 4
# Actual: 2 != 4

# %% [markdown]
# Create a scatter plot for the validation losses of models 1 and 2. What is your conclusion about the use of a convolutional layer? Explain your findings. Study the chainer documentation to get some hints for other tricks. If you continue your studies in this area, it is recommended to use low-level chainer code, to have firm control over its behavior.
